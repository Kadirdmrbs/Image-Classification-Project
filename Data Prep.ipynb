# %%
import os

# %%
data_dir = 'Large_Data/'

# %%
os.listdir(data_dir)
# Out:
# ['test', 'train', 'val']

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from matplotlib.image import imread

# %%
test_path = data_dir+'/test/'
train_path = data_dir+'/train/'

# %%
test_path
# Out:
# 'Large_Data//test/'

# %%
os.listdir(test_path)
# Out:
# ['bicycle',
#  'grass snake',
#  'jean',
#  'school bus',
#  'street sign',
#  'traffic light']

# %%
os.listdir(train_path+'bicycle')[1]
# Out:
# 'n02835271_10064.JPEG'

# %%
bicycle = train_path+'bicycle/'+'n02835271_10064.JPEG'
imread(bicycle).shape
# Out:
# (461, 691, 3)

# %%
plt.imshow(imread(bicycle))

# %%
dim1 = []
dim2 = []

for image_filename in os.listdir('Large_Data/test/bicycle'):
    
    img = imread('Large_Data/test/bicycle/'+image_filename)
    d1,d2,colors = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
sns.jointplot(dim1,dim2)

# %%
np.mean(dim1)
# Out:
# 388.2020202020202

# %%
np.mean(dim2)
# Out:
# 497.95959595959596
